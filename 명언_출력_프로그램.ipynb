# %% [markdown]
# <a href="https://colab.research.google.com/github/KimDeukGap/opensource/blob/main/%EB%AA%85%EC%96%B8_%EC%B6%9C%EB%A0%A5_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

quotes = [
    "성공은 준비와 기회의 만남이다. - 세네카",
    "오늘 할 수 있는 일을 내일로 미루지 말라. - 벤자민 프랭클린",
    "작은 습관이 큰 변화를 만든다.",
    "실패는 성공으로 가는 디딤돌이다.",
    "배움은 끝없는 여행이다."
]

def show_random_quote():
    print("\n=== 오늘의 명언 ===")
    print(random.choice(quotes))

def main():
    while True:
        cmd = input("\nEnter 키를 누르면 명언을 보여줍니다 (q 입력 시 종료): ")
        if cmd.lower() == "q":
            print("프로그램을 종료합니다.")
            break
        else:
            show_random_quote()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1718/3465534240.py in <cell line: 0>()
#      23
#      24 if __name__ == "__main__":
# ---> 25     main()
#
# /tmp/ipykernel_1718/3465534240.py in main()
#      15 def main():
#      16     while True:
# ---> 17         cmd = input("\nEnter 키를 누르면 명언을 보여줍니다 (q 입력 시 종료): ")
#      18         if cmd.lower() == "q":
#      19             print("프로그램을 종료합니다.")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
